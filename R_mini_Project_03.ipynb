# %% [markdown]
# <a href="https://colab.research.google.com/github/veena121/R-Lab/blob/main/R_mini_Project_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
abc <- read.csv("http://archive.ics.uci.edu/ml/machine-learning-databases/00537/sobar-72.csv")
abc
# Out:
#    behavior_sexualRisk behavior_eating behavior_personalHygine
# 1  10                  13              12
# 2  10                  11              11
# 3  10                  15               3
# 4  10                  11              10
# 5   8                  11               7
# 6  10                  14               8
# 7  10                  15               4
# 8   8                  12               9
# 9  10                  15               7
# 10  7                  15               7
# 11  7                  15               7
# 12 10                  15               8
# 13 10                  15              12
# 14  9                  12              14
# 15  2                  15              15
# 16 10                  15               7
# 17 10                  15               9
# 18 10                  12               7
# 19 10                  11              12
# 20 10                  12              12
# 21 10                  15              15
# ...

# %% [markdown]
# Task Number 5

# %%
# a. print the 5 point statistical summary for any 2 numeric attributes from your data set
fivenum(abc$behavior_eating) 
fivenum(abc$behavior_sexualRisk)
# Out:
# [1]  3 11 13 15 15
# [1]  2 10 10 10 10

# %%
# b. select 2 atributes have closest mean value and draw a scatter plot with proper x and labelsloi
# ntt and title (for plotting you must use R library functions or gnuplot and not matplotlib )
means<- colMeans(abc[sapply(abc, is.numeric)] )
means
# Out:
#        behavior_sexualRisk            behavior_eating
#                  9.6666667                 12.7916667
#    behavior_personalHygine      intention_aggregation
#                 11.0833333                  7.9027778
#       intention_commitment       attitude_consistency
#                 13.3472222                  7.1805556
#       attitude_spontaneity     norm_significantPerson
#                  8.6111111                  3.1250000
#           norm_fulfillment   perception_vulnerability
#                  8.4861111                  8.5138889
#        perception_severity        motivation_strength
#                  5.3888889                 12.6527778
#     motivation_willingness socialSupport_emotionality
#                  9.6944444                  8.0972222
# socialSupport_appreciation socialSupport_instrumental
#                  6.1666667                 10.3750000
#      empowerment_knowledge      empowerment_abilities
# ...

# %%
plot(abc$intention_commitment , abc$behavior_eating , main = "Scatterplot" , xlab = "intention_commitment", ylab = "behavior_eating" , las = 1 , xlim = c(0,25) , ylim=c(0,25) )
# Out:
# Plot with title “Scatterplot”

# %%
# e. Write a R function to plot histogram of some specific input attribute for any data set provided 
intention_aggregation <- abc$intention_aggregation 
new.function <- function(	intention_aggregation) {
   hist(	intention_aggregation)
}

new.function(	intention_aggregation)
# Out:
# Plot with title “Histogram of intention_aggregation”

# %%
# c. Find coefficient of correlation using some R library function between above 2 attributes
cor(abc$intention_commitment,abc$behavior_eating	, method ='pearson')
cor(abc$intention_commitment,abc$behavior_eating	, method ='kendall') 
cor(abc$intention_commitment,abc$behavior_eating	, method ='spearman')
# Out:
# [1] 0.1160748
# [1] 0.02356499
# [1] 0.02987251

# %%
boxplot(behavior_eating,intention_commitment)
title(" behavior_eating vs. intention_commitment")
# Out:
# Plot with title “ behavior_eating vs. intention_commitment”

# %%
boxplot(intention_aggregation~intention_commitment,abc=abc, main="Box Plot",
   xlab="behavior_eating", ylab="intention_commitment")
# Out:
# Plot with title “Box Plot”
